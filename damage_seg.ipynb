# %% [markdown]
# <a href="https://colab.research.google.com/github/bharshal/car_damage_detector/blob/master/damage_seg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# for augmentations
# !pip install albumentations==0.4.3

# for pretrained segmentation models fo PyTorch
# !pip install segmentation-models-pytorch==0.1.0

# for TTA
# !pip install ttach==0.0.2

# Catalyst itself
# !pip install -U catalyst

# for tensorboard
# !pip install tensorflow

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# !ls '/content/drive/My Drive/task_artivartic/dataset/'
# Out:
# damage_masks  part_masks  test	train  val

# %%
DATA_DIR = '/content/drive/My Drive/task_artivartic/dataset/'
x_train_dir1 = os.path.join(DATA_DIR, 'train')
y_train_dir1 = os.path.join(DATA_DIR, 'damage_masks')

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as BaseDataset

# %%
class Dataset(BaseDataset):
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['a']
    
    def __init__(
            self, 
            array_images_dir, 
            array_masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.images_fps = []
        self.masks_fps = []
        for i, images_dir in enumerate(array_images_dir):
            masks_dir = array_masks_dir[i]
            for file_name in os.listdir(images_dir):
                if file_name.split(".")[1] == "jpg":
                  image = images_dir+"/"+file_name
                  mask = masks_dir+"/"+file_name.split('.')[0]+".npy"
                  #print(image)
                  #image = cv2.imread(image)
                  #print(image.shape)
                  self.images_fps.append(image)
                  self.masks_fps.append(mask)            

        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        #print(self.images_fps[i])
        image = cv2.imread(self.images_fps[i])
        #print(image.shape)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        # print(self.masks_fps[i])
        mask = np.load(self.masks_fps[i])
        #mask = cv2.resize(mask, (image.shape[1], image.shape[0]), interpolation = cv2.INTER_AREA)
        mask = mask/255
        mask = mask[...,np.newaxis]
        #print("shape"+str(np.array(mask).shape))
        
        # extract certain classes from mask (e.g. cars)
        # masks = [(mask == v) for v in self.class_values]
        # mask = np.stack(masks, axis=-1).astype('float')
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.images_fps)

# %%
dataset = Dataset([x_train_dir1], [y_train_dir1], classes=['a'])

image, mask = dataset[12] # get some sample
print(image.shape)
print(mask.shape)
# Out:
# (1024, 1024, 3)
# (1024, 1024, 1)

# %%
visualize(
    image=image, 
    mask=mask.squeeze()
)

# %%
import albumentations as albu

# %%
def get_training_augmentation():
    train_transform = [

        albu.HorizontalFlip(p=0.5),

        albu.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        albu.PadIfNeeded(min_height=100, min_width=100, always_apply=True, border_mode=0),
        albu.RandomCrop(height=900, width=1000, always_apply=False),

        albu.IAAAdditiveGaussianNoise(p=0.2),
        albu.IAAPerspective(p=0.5),

        albu.OneOf(
            [
                albu.CLAHE(p=1),
                albu.RandomBrightness(p=1),
                albu.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        albu.OneOf(
            [
                albu.IAASharpen(p=1),
                albu.Blur(blur_limit=3, p=1),
                albu.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        albu.OneOf(
            [
                albu.RandomContrast(p=1),
                albu.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
    ]
    return albu.Compose(train_transform)

def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        albu.PadIfNeeded(384, 480)
    ]
    return albu.Compose(test_transform)


def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')

def get_preprocessing(preprocessing_fn, image_size=224):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        albu.Resize(image_size, image_size, p=1),
        albu.Lambda(image=preprocessing_fn),
        albu.Lambda(image=to_tensor, mask=to_tensor),
    ]
    return albu.Compose(_transform)

# %%
augmented_dataset = Dataset([x_train_dir1], [y_train_dir1], classes=['a'])

# same image with different random transforms
for i in range(2):
    image, mask = augmented_dataset[i]
    visualize(image=image, mask=mask.squeeze())

# %%
import torch
import numpy as np
import segmentation_models_pytorch as smp

# %%
ENCODER = 'resnet18'
ENCODER_WEIGHTS = 'imagenet'
CLASSES = ['a']
ACTIVATION = 'sigmoid' # could be None for logits or 'softmax2d' for multicalss segmentation
DEVICE = 'cuda'

model = smp.FPN(
    encoder_name=ENCODER,  
    encoder_weights=ENCODER_WEIGHTS, 
    classes=len(CLASSES), 
    activation=ACTIVATION,
)
#model = torch.load("./drive/My Drive/TTball_weights/best_model.pth")
preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# %%
train_dataset = Dataset(
    [x_train_dir1], 
    [y_train_dir1],
    augmentation=get_training_augmentation(), 
    preprocessing=get_preprocessing(preprocessing_fn),
    classes=CLASSES,
)

image, mask = train_dataset[10]
print(image.shape)
print(mask.shape)
#visualize(image=image, mask=mask[:,:,1])


x_valid_dir = os.path.join(DATA_DIR, 'val')
y_valid_dir = os.path.join(DATA_DIR, 'damage_masks/val')

valid_dataset = Dataset(
    [x_valid_dir], 
    [y_valid_dir], 
    augmentation=get_validation_augmentation(), 
    preprocessing=get_preprocessing(preprocessing_fn),
    classes=CLASSES,
)

train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True, num_workers=10)
valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False, num_workers=4)
# Out:
# (3, 224, 224)
# (1, 224, 224)
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2908: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "

# %%
# Dice/F1 score - https://en.wikipedia.org/wiki/S%C3%B8rensen%E2%80%93Dice_coefficient
# IoU/Jaccard score - https://en.wikipedia.org/wiki/Jaccard_index

loss = smp.utils.losses.DiceLoss()
metrics = [
    smp.utils.metrics.IoU(threshold=0.5),
]

optimizer = torch.optim.Adam([ 
    dict(params=model.parameters(), lr=0.0001),
])

# %%
# create epoch runners 
# it is a simple loop of iterating over dataloader`s samples

#model = torch.load('/content/drive/My Drive/task_artivartic/weights/segmentation_model.pth')
train_epoch = smp.utils.train.TrainEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    optimizer=optimizer,
    device=DEVICE,
    verbose=True,
)

valid_epoch = smp.utils.train.ValidEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    device=DEVICE,
    verbose=True,
)

# %%
#!mkdir '/content/drive/My Drive/task_artivartic/weights'
max_score = 0
#print(train_loader)
train_loss = []
val_loss = []
train_iou = []
val_iou = []

for i in range(0, 400):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = valid_epoch.run(valid_loader)
    
    train_loss.append(train_logs['dice_loss'])
    val_loss.append(valid_logs['dice_loss'])
    train_iou.append(train_logs['iou_score'])
    val_iou.append(valid_logs['iou_score'])
    # do something (save model, change lr, etc.)
    if max_score < valid_logs['iou_score']:
        max_score = valid_logs['iou_score']
        torch.save(model, '/content/drive/My Drive/task_artivartic/weights/damage_seg.pth')
        print('Model saved!')
        
    if i == 150:
        optimizer.param_groups[0]['lr'] = 1e-5
        print('Decrease decoder learning rate to 1e-5!')

print(train_loss)
print(val_loss)
print(train_iou)
print(val_iou)
# Out:
# Epoch: 0
# train: 100%|██████████| 31/31 [00:13<00:00,  2.27it/s, dice_loss - 0.721, iou_score - 0.1838]
# valid: 100%|██████████| 8/8 [00:04<00:00,  1.92it/s, dice_loss - 0.541, iou_score - 0.3498]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 31/31 [00:07<00:00,  3.89it/s, dice_loss - 0.5824, iou_score - 0.2911]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.67it/s, dice_loss - 0.4996, iou_score - 0.3678]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 31/31 [00:08<00:00,  3.58it/s, dice_loss - 0.5584, iou_score - 0.3154]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.68it/s, dice_loss - 0.661, iou_score - 0.2295]
#
# Epoch: 3
# train: 100%|██████████| 31/31 [00:07<00:00,  3.90it/s, dice_loss - 0.5267, iou_score - 0.336]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.87it/s, dice_loss - 0.5486, iou_score - 0.3203]
#
# Epoch: 4
# train: 100%|██████████| 31/31 [00:08<00:00,  3.87it/s, dice_loss - 0.4686, iou_score - 0.3802]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.01it/s, dice_loss - 0.6007, iou_score - 0.2776]
#
# Epoch: 5
# train: 100%|██████████| 31/31 [00:07<00:00,  3.94it/s, dice_loss - 0.4816, iou_score - 0.3723]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.31it/s, dice_loss - 0.6248, iou_score - 0.284]
#
# Epoch: 6
# train: 100%|██████████| 31/31 [00:08<00:00,  3.84it/s, dice_loss - 0.4849, iou_score - 0.3696]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.15it/s, dice_loss - 0.636, iou_score - 0.2667]
#
# Epoch: 7
# train: 100%|██████████| 31/31 [00:07<00:00,  3.97it/s, dice_loss - 0.4655, iou_score - 0.3867]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.06it/s, dice_loss - 0.664, iou_score - 0.2485]
#
# Epoch: 8
# train: 100%|██████████| 31/31 [00:08<00:00,  3.81it/s, dice_loss - 0.4616, iou_score - 0.3837]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.22it/s, dice_loss - 0.7258, iou_score - 0.1916]
#
# Epoch: 9
# train: 100%|██████████| 31/31 [00:08<00:00,  3.84it/s, dice_loss - 0.4327, iou_score - 0.4225]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.75it/s, dice_loss - 0.667, iou_score - 0.2354]
#
# Epoch: 10
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.4317, iou_score - 0.4229]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.99it/s, dice_loss - 0.6508, iou_score - 0.2462]
#
# Epoch: 11
# train: 100%|██████████| 31/31 [00:08<00:00,  3.66it/s, dice_loss - 0.4097, iou_score - 0.4456]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.10it/s, dice_loss - 0.6574, iou_score - 0.2377]
#
# Epoch: 12
# train: 100%|██████████| 31/31 [00:07<00:00,  4.05it/s, dice_loss - 0.4395, iou_score - 0.4224]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.63it/s, dice_loss - 0.5954, iou_score - 0.2784]
#
# Epoch: 13
# train: 100%|██████████| 31/31 [00:07<00:00,  4.07it/s, dice_loss - 0.4135, iou_score - 0.4399]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.88it/s, dice_loss - 0.7693, iou_score - 0.1524]
#
# Epoch: 14
# train: 100%|██████████| 31/31 [00:07<00:00,  4.15it/s, dice_loss - 0.4048, iou_score - 0.4427]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.11it/s, dice_loss - 0.6781, iou_score - 0.2239]
#
# Epoch: 15
# train: 100%|██████████| 31/31 [00:07<00:00,  4.10it/s, dice_loss - 0.3915, iou_score - 0.4617]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.76it/s, dice_loss - 0.7599, iou_score - 0.1673]
#
# Epoch: 16
# train: 100%|██████████| 31/31 [00:08<00:00,  3.84it/s, dice_loss - 0.3837, iou_score - 0.467]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.95it/s, dice_loss - 0.667, iou_score - 0.2376]
#
# Epoch: 17
# train: 100%|██████████| 31/31 [00:08<00:00,  3.76it/s, dice_loss - 0.3953, iou_score - 0.4585]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.73it/s, dice_loss - 0.5133, iou_score - 0.3567]
#
# Epoch: 18
# train: 100%|██████████| 31/31 [00:07<00:00,  4.04it/s, dice_loss - 0.3621, iou_score - 0.4886]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.71it/s, dice_loss - 0.6249, iou_score - 0.2625]
#
# Epoch: 19
# train: 100%|██████████| 31/31 [00:08<00:00,  3.69it/s, dice_loss - 0.3741, iou_score - 0.4776]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.76it/s, dice_loss - 0.6281, iou_score - 0.2541]
#
# Epoch: 20
# train: 100%|██████████| 31/31 [00:07<00:00,  3.99it/s, dice_loss - 0.4093, iou_score - 0.446]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.59it/s, dice_loss - 0.6464, iou_score - 0.2408]
#
# Epoch: 21
# train: 100%|██████████| 31/31 [00:07<00:00,  4.17it/s, dice_loss - 0.3444, iou_score - 0.5074]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.90it/s, dice_loss - 0.7184, iou_score - 0.1964]
#
# Epoch: 22
# train: 100%|██████████| 31/31 [00:07<00:00,  4.15it/s, dice_loss - 0.3297, iou_score - 0.5204]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.97it/s, dice_loss - 0.7241, iou_score - 0.198]
#
# Epoch: 23
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.3433, iou_score - 0.507]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.79it/s, dice_loss - 0.6127, iou_score - 0.2714]
#
# Epoch: 24
# train: 100%|██████████| 31/31 [00:08<00:00,  3.69it/s, dice_loss - 0.3669, iou_score - 0.4855]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.10it/s, dice_loss - 0.7268, iou_score - 0.1939]
#
# Epoch: 25
# train: 100%|██████████| 31/31 [00:07<00:00,  4.05it/s, dice_loss - 0.3867, iou_score - 0.4675]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.13it/s, dice_loss - 0.6782, iou_score - 0.2282]
#
# Epoch: 26
# train: 100%|██████████| 31/31 [00:07<00:00,  3.95it/s, dice_loss - 0.3357, iou_score - 0.5251]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.43it/s, dice_loss - 0.7137, iou_score - 0.1972]
#
# Epoch: 27
# train: 100%|██████████| 31/31 [00:08<00:00,  3.66it/s, dice_loss - 0.3469, iou_score - 0.5041]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.14it/s, dice_loss - 0.5887, iou_score - 0.2827]
#
# Epoch: 28
# train: 100%|██████████| 31/31 [00:07<00:00,  4.24it/s, dice_loss - 0.3502, iou_score - 0.4972]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.56it/s, dice_loss - 0.6261, iou_score - 0.2644]
#
# Epoch: 29
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.3169, iou_score - 0.5395]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.79it/s, dice_loss - 0.5371, iou_score - 0.33]
#
# Epoch: 30
# train: 100%|██████████| 31/31 [00:08<00:00,  3.86it/s, dice_loss - 0.3355, iou_score - 0.5181]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.96it/s, dice_loss - 0.592, iou_score - 0.2784]
#
# Epoch: 31
# train: 100%|██████████| 31/31 [00:07<00:00,  3.93it/s, dice_loss - 0.2996, iou_score - 0.5569]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.24it/s, dice_loss - 0.6506, iou_score - 0.2381]
#
# Epoch: 32
# train: 100%|██████████| 31/31 [00:07<00:00,  4.01it/s, dice_loss - 0.3529, iou_score - 0.5023]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.01it/s, dice_loss - 0.6089, iou_score - 0.2804]
#
# Epoch: 33
# train: 100%|██████████| 31/31 [00:08<00:00,  3.71it/s, dice_loss - 0.3146, iou_score - 0.5421]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.89it/s, dice_loss - 0.638, iou_score - 0.2559]
#
# Epoch: 34
# train: 100%|██████████| 31/31 [00:07<00:00,  4.01it/s, dice_loss - 0.3277, iou_score - 0.5297]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.08it/s, dice_loss - 0.6348, iou_score - 0.2587]
#
# Epoch: 35
# train: 100%|██████████| 31/31 [00:07<00:00,  4.02it/s, dice_loss - 0.3075, iou_score - 0.5475]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.89it/s, dice_loss - 0.604, iou_score - 0.2811]
#
# Epoch: 36
# train: 100%|██████████| 31/31 [00:08<00:00,  3.69it/s, dice_loss - 0.2881, iou_score - 0.5733]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.86it/s, dice_loss - 0.5661, iou_score - 0.3069]
#
# Epoch: 37
# train: 100%|██████████| 31/31 [00:07<00:00,  4.02it/s, dice_loss - 0.3367, iou_score - 0.5215]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.70it/s, dice_loss - 0.5038, iou_score - 0.3557]
#
# Epoch: 38
# train: 100%|██████████| 31/31 [00:07<00:00,  3.91it/s, dice_loss - 0.3167, iou_score - 0.5374]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.97it/s, dice_loss - 0.5079, iou_score - 0.3499]
#
# Epoch: 39
# train: 100%|██████████| 31/31 [00:07<00:00,  3.97it/s, dice_loss - 0.3071, iou_score - 0.5462]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.26it/s, dice_loss - 0.51, iou_score - 0.357]
#
# Epoch: 40
# train: 100%|██████████| 31/31 [00:08<00:00,  3.86it/s, dice_loss - 0.3236, iou_score - 0.5301]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.90it/s, dice_loss - 0.5861, iou_score - 0.2911]
#
# Epoch: 41
# train: 100%|██████████| 31/31 [00:07<00:00,  3.96it/s, dice_loss - 0.287, iou_score - 0.5705]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.03it/s, dice_loss - 0.513, iou_score - 0.3551]
#
# Epoch: 42
# train: 100%|██████████| 31/31 [00:07<00:00,  3.99it/s, dice_loss - 0.2989, iou_score - 0.5612]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.22it/s, dice_loss - 0.5769, iou_score - 0.2977]
#
# Epoch: 43
# train: 100%|██████████| 31/31 [00:08<00:00,  3.80it/s, dice_loss - 0.3052, iou_score - 0.5503]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.84it/s, dice_loss - 0.5318, iou_score - 0.3366]
#
# Epoch: 44
# train: 100%|██████████| 31/31 [00:07<00:00,  3.89it/s, dice_loss - 0.2959, iou_score - 0.5667]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.63it/s, dice_loss - 0.5983, iou_score - 0.2819]
#
# Epoch: 45
# train: 100%|██████████| 31/31 [00:08<00:00,  3.81it/s, dice_loss - 0.3004, iou_score - 0.5528]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.11it/s, dice_loss - 0.5449, iou_score - 0.3275]
#
# Epoch: 46
# train: 100%|██████████| 31/31 [00:07<00:00,  3.96it/s, dice_loss - 0.2637, iou_score - 0.5985]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.65it/s, dice_loss - 0.5748, iou_score - 0.3004]
#
# Epoch: 47
# train: 100%|██████████| 31/31 [00:08<00:00,  3.82it/s, dice_loss - 0.2901, iou_score - 0.5729]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.08it/s, dice_loss - 0.5173, iou_score - 0.3485]
#
# Epoch: 48
# train: 100%|██████████| 31/31 [00:07<00:00,  3.99it/s, dice_loss - 0.3002, iou_score - 0.5599]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.27it/s, dice_loss - 0.5058, iou_score - 0.3537]
#
# Epoch: 49
# train: 100%|██████████| 31/31 [00:07<00:00,  3.90it/s, dice_loss - 0.3194, iou_score - 0.5349]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.65it/s, dice_loss - 0.5724, iou_score - 0.3082]
#
# Epoch: 50
# train: 100%|██████████| 31/31 [00:08<00:00,  3.80it/s, dice_loss - 0.3233, iou_score - 0.54]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.28it/s, dice_loss - 0.4911, iou_score - 0.3562]
#
# Epoch: 51
# train: 100%|██████████| 31/31 [00:07<00:00,  4.07it/s, dice_loss - 0.2965, iou_score - 0.5628]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.86it/s, dice_loss - 0.6044, iou_score - 0.2818]
#
# Epoch: 52
# train: 100%|██████████| 31/31 [00:07<00:00,  4.18it/s, dice_loss - 0.2842, iou_score - 0.5812]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.35it/s, dice_loss - 0.6251, iou_score - 0.2586]
#
# Epoch: 53
# train: 100%|██████████| 31/31 [00:08<00:00,  3.80it/s, dice_loss - 0.2737, iou_score - 0.5924]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.92it/s, dice_loss - 0.4611, iou_score - 0.405]
# Model saved!
#
# Epoch: 54
# train: 100%|██████████| 31/31 [00:08<00:00,  3.84it/s, dice_loss - 0.2509, iou_score - 0.6128]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.00it/s, dice_loss - 0.4839, iou_score - 0.3782]
#
# Epoch: 55
# train: 100%|██████████| 31/31 [00:07<00:00,  3.90it/s, dice_loss - 0.281, iou_score - 0.5841]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.08it/s, dice_loss - 0.4896, iou_score - 0.3781]
#
# Epoch: 56
# train: 100%|██████████| 31/31 [00:07<00:00,  3.91it/s, dice_loss - 0.2784, iou_score - 0.5821]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.90it/s, dice_loss - 0.5023, iou_score - 0.3538]
#
# Epoch: 57
# train: 100%|██████████| 31/31 [00:07<00:00,  4.07it/s, dice_loss - 0.2321, iou_score - 0.6386]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.25it/s, dice_loss - 0.4743, iou_score - 0.379]
#
# Epoch: 58
# train: 100%|██████████| 31/31 [00:08<00:00,  3.86it/s, dice_loss - 0.2642, iou_score - 0.6016]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.57it/s, dice_loss - 0.4791, iou_score - 0.3789]
#
# Epoch: 59
# train: 100%|██████████| 31/31 [00:08<00:00,  3.74it/s, dice_loss - 0.2622, iou_score - 0.6022]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.52it/s, dice_loss - 0.4428, iou_score - 0.4071]
# Model saved!
#
# Epoch: 60
# train: 100%|██████████| 31/31 [00:08<00:00,  3.75it/s, dice_loss - 0.2576, iou_score - 0.6093]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.20it/s, dice_loss - 0.443, iou_score - 0.4068]
#
# Epoch: 61
# train: 100%|██████████| 31/31 [00:08<00:00,  3.83it/s, dice_loss - 0.2772, iou_score - 0.5954]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.94it/s, dice_loss - 0.4888, iou_score - 0.3626]
#
# Epoch: 62
# train: 100%|██████████| 31/31 [00:07<00:00,  3.99it/s, dice_loss - 0.2674, iou_score - 0.5923]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.70it/s, dice_loss - 0.5737, iou_score - 0.3012]
#
# Epoch: 63
# train: 100%|██████████| 31/31 [00:07<00:00,  3.96it/s, dice_loss - 0.2439, iou_score - 0.6194]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.91it/s, dice_loss - 0.4877, iou_score - 0.3618]
#
# Epoch: 64
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.2613, iou_score - 0.5978]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.04it/s, dice_loss - 0.5506, iou_score - 0.3142]
#
# Epoch: 65
# train: 100%|██████████| 31/31 [00:07<00:00,  3.97it/s, dice_loss - 0.2703, iou_score - 0.5932]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.36it/s, dice_loss - 0.6269, iou_score - 0.255]
#
# Epoch: 66
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.22, iou_score - 0.6542]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.44it/s, dice_loss - 0.5258, iou_score - 0.3407]
#
# Epoch: 67
# train: 100%|██████████| 31/31 [00:07<00:00,  3.96it/s, dice_loss - 0.2422, iou_score - 0.63]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.17it/s, dice_loss - 0.5226, iou_score - 0.3391]
#
# Epoch: 68
# train: 100%|██████████| 31/31 [00:07<00:00,  3.96it/s, dice_loss - 0.2402, iou_score - 0.6289]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.20it/s, dice_loss - 0.5697, iou_score - 0.3094]
#
# Epoch: 69
# train: 100%|██████████| 31/31 [00:08<00:00,  3.75it/s, dice_loss - 0.2549, iou_score - 0.6132]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.50it/s, dice_loss - 0.5591, iou_score - 0.3131]
#
# Epoch: 70
# train: 100%|██████████| 31/31 [00:07<00:00,  3.89it/s, dice_loss - 0.272, iou_score - 0.5911]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.41it/s, dice_loss - 0.5169, iou_score - 0.3498]
#
# Epoch: 71
# train: 100%|██████████| 31/31 [00:08<00:00,  3.83it/s, dice_loss - 0.2453, iou_score - 0.6321]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.80it/s, dice_loss - 0.5654, iou_score - 0.3044]
#
# Epoch: 72
# train: 100%|██████████| 31/31 [00:08<00:00,  3.81it/s, dice_loss - 0.2629, iou_score - 0.604]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.10it/s, dice_loss - 0.4648, iou_score - 0.4018]
#
# Epoch: 73
# train: 100%|██████████| 31/31 [00:08<00:00,  3.68it/s, dice_loss - 0.22, iou_score - 0.656]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.54it/s, dice_loss - 0.4689, iou_score - 0.3944]
#
# Epoch: 74
# train: 100%|██████████| 31/31 [00:07<00:00,  4.15it/s, dice_loss - 0.2597, iou_score - 0.6139]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.77it/s, dice_loss - 0.4379, iou_score - 0.4118]
# Model saved!
#
# Epoch: 75
# train: 100%|██████████| 31/31 [00:07<00:00,  3.91it/s, dice_loss - 0.238, iou_score - 0.631]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.58it/s, dice_loss - 0.4284, iou_score - 0.4272]
# Model saved!
#
# Epoch: 76
# train: 100%|██████████| 31/31 [00:08<00:00,  3.71it/s, dice_loss - 0.2608, iou_score - 0.609]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.44it/s, dice_loss - 0.4215, iou_score - 0.4303]
# Model saved!
#
# Epoch: 77
# train: 100%|██████████| 31/31 [00:08<00:00,  3.69it/s, dice_loss - 0.2672, iou_score - 0.5984]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.15it/s, dice_loss - 0.4391, iou_score - 0.4132]
#
# Epoch: 78
# train: 100%|██████████| 31/31 [00:08<00:00,  3.82it/s, dice_loss - 0.257, iou_score - 0.6073]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.29it/s, dice_loss - 0.6001, iou_score - 0.2757]
#
# Epoch: 79
# train: 100%|██████████| 31/31 [00:08<00:00,  3.79it/s, dice_loss - 0.2858, iou_score - 0.5906]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.38it/s, dice_loss - 0.467, iou_score - 0.386]
#
# Epoch: 80
# train: 100%|██████████| 31/31 [00:07<00:00,  4.08it/s, dice_loss - 0.2307, iou_score - 0.6437]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.26it/s, dice_loss - 0.5861, iou_score - 0.2974]
#
# Epoch: 81
# train: 100%|██████████| 31/31 [00:07<00:00,  3.96it/s, dice_loss - 0.2237, iou_score - 0.6548]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.31it/s, dice_loss - 0.5916, iou_score - 0.2882]
#
# Epoch: 82
# train: 100%|██████████| 31/31 [00:07<00:00,  3.89it/s, dice_loss - 0.227, iou_score - 0.6474]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.44it/s, dice_loss - 0.4799, iou_score - 0.3715]
#
# Epoch: 83
# train: 100%|██████████| 31/31 [00:08<00:00,  3.76it/s, dice_loss - 0.2346, iou_score - 0.6434]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.22it/s, dice_loss - 0.4465, iou_score - 0.4058]
#
# Epoch: 84
# train: 100%|██████████| 31/31 [00:08<00:00,  3.85it/s, dice_loss - 0.2383, iou_score - 0.6398]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.94it/s, dice_loss - 0.5115, iou_score - 0.3541]
#
# Epoch: 85
# train: 100%|██████████| 31/31 [00:08<00:00,  3.83it/s, dice_loss - 0.2812, iou_score - 0.5818]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.24it/s, dice_loss - 0.4852, iou_score - 0.3828]
#
# Epoch: 86
# train: 100%|██████████| 31/31 [00:08<00:00,  3.83it/s, dice_loss - 0.2882, iou_score - 0.5789]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.04it/s, dice_loss - 0.4817, iou_score - 0.3906]
#
# Epoch: 87
# train: 100%|██████████| 31/31 [00:08<00:00,  3.78it/s, dice_loss - 0.2405, iou_score - 0.6316]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.56it/s, dice_loss - 0.4675, iou_score - 0.4034]
#
# Epoch: 88
# train: 100%|██████████| 31/31 [00:07<00:00,  4.03it/s, dice_loss - 0.2372, iou_score - 0.6337]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.46it/s, dice_loss - 0.4676, iou_score - 0.3886]
#
# Epoch: 89
# train: 100%|██████████| 31/31 [00:07<00:00,  4.14it/s, dice_loss - 0.2278, iou_score - 0.6484]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.14it/s, dice_loss - 0.5092, iou_score - 0.3704]
#
# Epoch: 90
# train: 100%|██████████| 31/31 [00:08<00:00,  3.75it/s, dice_loss - 0.2489, iou_score - 0.6183]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.27it/s, dice_loss - 0.5297, iou_score - 0.3499]
#
# Epoch: 91
# train: 100%|██████████| 31/31 [00:07<00:00,  4.04it/s, dice_loss - 0.2052, iou_score - 0.6728]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.65it/s, dice_loss - 0.4837, iou_score - 0.393]
#
# Epoch: 92
# train: 100%|██████████| 31/31 [00:07<00:00,  3.93it/s, dice_loss - 0.2038, iou_score - 0.6784]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.23it/s, dice_loss - 0.4962, iou_score - 0.3781]
#
# Epoch: 93
# train: 100%|██████████| 31/31 [00:08<00:00,  3.78it/s, dice_loss - 0.2079, iou_score - 0.6703]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.18it/s, dice_loss - 0.4455, iou_score - 0.4182]
#
# Epoch: 94
# train: 100%|██████████| 31/31 [00:08<00:00,  3.86it/s, dice_loss - 0.2208, iou_score - 0.65]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.36it/s, dice_loss - 0.4762, iou_score - 0.3813]
#
# Epoch: 95
# train: 100%|██████████| 31/31 [00:08<00:00,  3.81it/s, dice_loss - 0.1909, iou_score - 0.6892]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.14it/s, dice_loss - 0.5854, iou_score - 0.2955]
#
# Epoch: 96
# train: 100%|██████████| 31/31 [00:07<00:00,  3.96it/s, dice_loss - 0.2064, iou_score - 0.6732]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.12it/s, dice_loss - 0.5428, iou_score - 0.3413]
#
# Epoch: 97
# train: 100%|██████████| 31/31 [00:07<00:00,  4.08it/s, dice_loss - 0.2124, iou_score - 0.6692]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.36it/s, dice_loss - 0.4609, iou_score - 0.402]
#
# Epoch: 98
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.2251, iou_score - 0.6531]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.33it/s, dice_loss - 0.439, iou_score - 0.4346]
# Model saved!
#
# Epoch: 99
# train: 100%|██████████| 31/31 [00:07<00:00,  3.96it/s, dice_loss - 0.1941, iou_score - 0.6876]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.99it/s, dice_loss - 0.4703, iou_score - 0.4015]
#
# Epoch: 100
# train: 100%|██████████| 31/31 [00:07<00:00,  3.90it/s, dice_loss - 0.2339, iou_score - 0.6394]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.82it/s, dice_loss - 0.6322, iou_score - 0.2725]
#
# Epoch: 101
# train: 100%|██████████| 31/31 [00:07<00:00,  4.02it/s, dice_loss - 0.1792, iou_score - 0.709]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.59it/s, dice_loss - 0.5891, iou_score - 0.3022]
#
# Epoch: 102
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.2124, iou_score - 0.6635]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.83it/s, dice_loss - 0.5219, iou_score - 0.3642]
#
# Epoch: 103
# train: 100%|██████████| 31/31 [00:07<00:00,  3.98it/s, dice_loss - 0.2301, iou_score - 0.6523]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.64it/s, dice_loss - 0.4566, iou_score - 0.4168]
#
# Epoch: 104
# train: 100%|██████████| 31/31 [00:07<00:00,  3.91it/s, dice_loss - 0.1962, iou_score - 0.6907]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.90it/s, dice_loss - 0.5559, iou_score - 0.3285]
#
# Epoch: 105
# train: 100%|██████████| 31/31 [00:08<00:00,  3.80it/s, dice_loss - 0.2202, iou_score - 0.6556]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.47it/s, dice_loss - 0.5169, iou_score - 0.354]
#
# Epoch: 106
# train: 100%|██████████| 31/31 [00:07<00:00,  3.90it/s, dice_loss - 0.1969, iou_score - 0.6811]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.26it/s, dice_loss - 0.4803, iou_score - 0.3879]
#
# Epoch: 107
# train: 100%|██████████| 31/31 [00:07<00:00,  4.06it/s, dice_loss - 0.1899, iou_score - 0.6961]
# valid: 100%|██████████| 8/8 [00:00<00:00, 15.01it/s, dice_loss - 0.4769, iou_score - 0.4014]
#
# Epoch: 108
# train: 100%|██████████| 31/31 [00:07<00:00,  3.96it/s, dice_loss - 0.2812, iou_score - 0.5903]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.71it/s, dice_loss - 0.4567, iou_score - 0.3984]
#
# Epoch: 109
# train: 100%|██████████| 31/31 [00:07<00:00,  4.20it/s, dice_loss - 0.2288, iou_score - 0.6466]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.52it/s, dice_loss - 0.4543, iou_score - 0.4049]
#
# Epoch: 110
# train: 100%|██████████| 31/31 [00:07<00:00,  4.01it/s, dice_loss - 0.2282, iou_score - 0.6442]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.02it/s, dice_loss - 0.4563, iou_score - 0.4081]
#
# Epoch: 111
# train: 100%|██████████| 31/31 [00:07<00:00,  3.93it/s, dice_loss - 0.1874, iou_score - 0.6935]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.18it/s, dice_loss - 0.4134, iou_score - 0.446]
# Model saved!
#
# Epoch: 112
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.1918, iou_score - 0.6893]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.23it/s, dice_loss - 0.4497, iou_score - 0.4358]
#
# Epoch: 113
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.2154, iou_score - 0.6607]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.80it/s, dice_loss - 0.451, iou_score - 0.4268]
#
# Epoch: 114
# train: 100%|██████████| 31/31 [00:07<00:00,  3.98it/s, dice_loss - 0.2198, iou_score - 0.6553]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.72it/s, dice_loss - 0.4551, iou_score - 0.4165]
#
# Epoch: 115
# train: 100%|██████████| 31/31 [00:07<00:00,  3.93it/s, dice_loss - 0.2032, iou_score - 0.6786]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.30it/s, dice_loss - 0.43, iou_score - 0.4397]
#
# Epoch: 116
# train: 100%|██████████| 31/31 [00:08<00:00,  3.81it/s, dice_loss - 0.1866, iou_score - 0.6988]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.88it/s, dice_loss - 0.4085, iou_score - 0.4549]
# Model saved!
#
# Epoch: 117
# train: 100%|██████████| 31/31 [00:07<00:00,  4.25it/s, dice_loss - 0.1981, iou_score - 0.6861]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.67it/s, dice_loss - 0.3924, iou_score - 0.471]
# Model saved!
#
# Epoch: 118
# train: 100%|██████████| 31/31 [00:07<00:00,  3.99it/s, dice_loss - 0.1964, iou_score - 0.686]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.40it/s, dice_loss - 0.4053, iou_score - 0.456]
#
# Epoch: 119
# train: 100%|██████████| 31/31 [00:08<00:00,  3.87it/s, dice_loss - 0.2066, iou_score - 0.6673]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.18it/s, dice_loss - 0.4124, iou_score - 0.4504]
#
# Epoch: 120
# train: 100%|██████████| 31/31 [00:08<00:00,  3.87it/s, dice_loss - 0.2028, iou_score - 0.6856]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.74it/s, dice_loss - 0.4286, iou_score - 0.4334]
#
# Epoch: 121
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.1951, iou_score - 0.6891]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.56it/s, dice_loss - 0.4503, iou_score - 0.4207]
#
# Epoch: 122
# train: 100%|██████████| 31/31 [00:07<00:00,  3.90it/s, dice_loss - 0.1993, iou_score - 0.6844]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.01it/s, dice_loss - 0.3941, iou_score - 0.4634]
#
# Epoch: 123
# train: 100%|██████████| 31/31 [00:07<00:00,  3.94it/s, dice_loss - 0.2195, iou_score - 0.6582]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.56it/s, dice_loss - 0.4284, iou_score - 0.4316]
#
# Epoch: 124
# train: 100%|██████████| 31/31 [00:07<00:00,  3.95it/s, dice_loss - 0.2054, iou_score - 0.6762]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.98it/s, dice_loss - 0.475, iou_score - 0.3945]
#
# Epoch: 125
# train: 100%|██████████| 31/31 [00:07<00:00,  4.00it/s, dice_loss - 0.2001, iou_score - 0.6871]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.59it/s, dice_loss - 0.4194, iou_score - 0.4445]
#
# Epoch: 126
# train: 100%|██████████| 31/31 [00:07<00:00,  3.95it/s, dice_loss - 0.1949, iou_score - 0.6873]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.47it/s, dice_loss - 0.3803, iou_score - 0.4791]
# Model saved!
#
# Epoch: 127
# train: 100%|██████████| 31/31 [00:07<00:00,  4.12it/s, dice_loss - 0.1893, iou_score - 0.6968]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.47it/s, dice_loss - 0.4167, iou_score - 0.4499]
#
# Epoch: 128
# train: 100%|██████████| 31/31 [00:08<00:00,  3.86it/s, dice_loss - 0.1963, iou_score - 0.6871]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.60it/s, dice_loss - 0.4313, iou_score - 0.4502]
#
# Epoch: 129
# train: 100%|██████████| 31/31 [00:07<00:00,  3.95it/s, dice_loss - 0.1979, iou_score - 0.6934]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.38it/s, dice_loss - 0.4656, iou_score - 0.4228]
#
# Epoch: 130
# train: 100%|██████████| 31/31 [00:08<00:00,  3.83it/s, dice_loss - 0.1832, iou_score - 0.7036]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.86it/s, dice_loss - 0.4755, iou_score - 0.399]
#
# Epoch: 131
# train: 100%|██████████| 31/31 [00:07<00:00,  3.89it/s, dice_loss - 0.1884, iou_score - 0.6938]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.30it/s, dice_loss - 0.4332, iou_score - 0.4267]
#
# Epoch: 132
# train: 100%|██████████| 31/31 [00:07<00:00,  3.90it/s, dice_loss - 0.1766, iou_score - 0.7134]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.52it/s, dice_loss - 0.418, iou_score - 0.446]
#
# Epoch: 133
# train: 100%|██████████| 31/31 [00:08<00:00,  3.78it/s, dice_loss - 0.1822, iou_score - 0.7038]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.45it/s, dice_loss - 0.4343, iou_score - 0.4315]
#
# Epoch: 134
# train: 100%|██████████| 31/31 [00:08<00:00,  3.74it/s, dice_loss - 0.1787, iou_score - 0.713]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.42it/s, dice_loss - 0.444, iou_score - 0.4373]
#
# Epoch: 135
# train: 100%|██████████| 31/31 [00:08<00:00,  3.84it/s, dice_loss - 0.1804, iou_score - 0.7077]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.59it/s, dice_loss - 0.4259, iou_score - 0.4517]
#
# Epoch: 136
# train: 100%|██████████| 31/31 [00:07<00:00,  3.96it/s, dice_loss - 0.1926, iou_score - 0.6958]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.19it/s, dice_loss - 0.4546, iou_score - 0.4295]
#
# Epoch: 137
# train: 100%|██████████| 31/31 [00:07<00:00,  4.00it/s, dice_loss - 0.1829, iou_score - 0.7057]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.46it/s, dice_loss - 0.4375, iou_score - 0.434]
#
# Epoch: 138
# train: 100%|██████████| 31/31 [00:07<00:00,  4.16it/s, dice_loss - 0.1806, iou_score - 0.7078]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.45it/s, dice_loss - 0.4299, iou_score - 0.4421]
#
# Epoch: 139
# train: 100%|██████████| 31/31 [00:08<00:00,  3.64it/s, dice_loss - 0.174, iou_score - 0.7197]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.93it/s, dice_loss - 0.4175, iou_score - 0.4593]
#
# Epoch: 140
# train: 100%|██████████| 31/31 [00:07<00:00,  3.95it/s, dice_loss - 0.177, iou_score - 0.71]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.42it/s, dice_loss - 0.4314, iou_score - 0.443]
#
# Epoch: 141
# train: 100%|██████████| 31/31 [00:07<00:00,  3.94it/s, dice_loss - 0.1541, iou_score - 0.7432]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.54it/s, dice_loss - 0.422, iou_score - 0.4468]
#
# Epoch: 142
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.2112, iou_score - 0.6787]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.73it/s, dice_loss - 0.4834, iou_score - 0.39]
#
# Epoch: 143
# train: 100%|██████████| 31/31 [00:07<00:00,  4.07it/s, dice_loss - 0.1731, iou_score - 0.7172]
# valid: 100%|██████████| 8/8 [00:00<00:00, 15.05it/s, dice_loss - 0.4589, iou_score - 0.3978]
#
# Epoch: 144
# train: 100%|██████████| 31/31 [00:07<00:00,  3.98it/s, dice_loss - 0.1826, iou_score - 0.7064]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.78it/s, dice_loss - 0.4731, iou_score - 0.3797]
#
# Epoch: 145
# train: 100%|██████████| 31/31 [00:07<00:00,  4.03it/s, dice_loss - 0.1701, iou_score - 0.7197]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.43it/s, dice_loss - 0.4388, iou_score - 0.421]
#
# Epoch: 146
# train: 100%|██████████| 31/31 [00:07<00:00,  4.08it/s, dice_loss - 0.1702, iou_score - 0.7235]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.94it/s, dice_loss - 0.3901, iou_score - 0.4688]
#
# Epoch: 147
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.1621, iou_score - 0.7342]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.22it/s, dice_loss - 0.4695, iou_score - 0.3978]
#
# Epoch: 148
# train: 100%|██████████| 31/31 [00:08<00:00,  3.64it/s, dice_loss - 0.1874, iou_score - 0.7062]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.99it/s, dice_loss - 0.4162, iou_score - 0.4587]
#
# Epoch: 149
# train: 100%|██████████| 31/31 [00:07<00:00,  4.00it/s, dice_loss - 0.1786, iou_score - 0.7112]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.94it/s, dice_loss - 0.4095, iou_score - 0.4611]
#
# Epoch: 150
# train: 100%|██████████| 31/31 [00:07<00:00,  3.88it/s, dice_loss - 0.1698, iou_score - 0.724]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.22it/s, dice_loss - 0.4246, iou_score - 0.4451]
# Decrease decoder learning rate to 1e-5!
#
# Epoch: 151
# train: 100%|██████████| 31/31 [00:08<00:00,  3.87it/s, dice_loss - 0.1525, iou_score - 0.7485]
# valid: 100%|██████████| 8/8 [00:00<00:00, 15.07it/s, dice_loss - 0.4283, iou_score - 0.442]
#
# Epoch: 152
# train: 100%|██████████| 31/31 [00:08<00:00,  3.72it/s, dice_loss - 0.1862, iou_score - 0.7052]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.26it/s, dice_loss - 0.4201, iou_score - 0.4488]
#
# Epoch: 153
# train: 100%|██████████| 31/31 [00:08<00:00,  3.76it/s, dice_loss - 0.1592, iou_score - 0.7382]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.93it/s, dice_loss - 0.4182, iou_score - 0.4479]
#
# Epoch: 154
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.1581, iou_score - 0.7405]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.45it/s, dice_loss - 0.4247, iou_score - 0.4444]
#
# Epoch: 155
# train: 100%|██████████| 31/31 [00:07<00:00,  3.94it/s, dice_loss - 0.149, iou_score - 0.7532]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.15it/s, dice_loss - 0.4093, iou_score - 0.4557]
#
# Epoch: 156
# train: 100%|██████████| 31/31 [00:07<00:00,  3.94it/s, dice_loss - 0.1627, iou_score - 0.7372]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.32it/s, dice_loss - 0.409, iou_score - 0.4583]
#
# Epoch: 157
# train: 100%|██████████| 31/31 [00:08<00:00,  3.78it/s, dice_loss - 0.1512, iou_score - 0.7521]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.45it/s, dice_loss - 0.4092, iou_score - 0.4618]
#
# Epoch: 158
# train: 100%|██████████| 31/31 [00:07<00:00,  4.16it/s, dice_loss - 0.1383, iou_score - 0.7713]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.47it/s, dice_loss - 0.4153, iou_score - 0.4557]
#
# Epoch: 159
# train: 100%|██████████| 31/31 [00:08<00:00,  3.78it/s, dice_loss - 0.1659, iou_score - 0.7315]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.60it/s, dice_loss - 0.4139, iou_score - 0.4522]
#
# Epoch: 160
# train: 100%|██████████| 31/31 [00:07<00:00,  3.99it/s, dice_loss - 0.1596, iou_score - 0.7408]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.20it/s, dice_loss - 0.4123, iou_score - 0.4583]
#
# Epoch: 161
# train: 100%|██████████| 31/31 [00:07<00:00,  4.32it/s, dice_loss - 0.1487, iou_score - 0.7554]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.63it/s, dice_loss - 0.4137, iou_score - 0.4559]
#
# Epoch: 162
# train: 100%|██████████| 31/31 [00:08<00:00,  3.73it/s, dice_loss - 0.1746, iou_score - 0.7231]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.45it/s, dice_loss - 0.4034, iou_score - 0.4622]
#
# Epoch: 163
# train: 100%|██████████| 31/31 [00:08<00:00,  3.82it/s, dice_loss - 0.1543, iou_score - 0.7473]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.11it/s, dice_loss - 0.4088, iou_score - 0.4576]
#
# Epoch: 164
# train: 100%|██████████| 31/31 [00:08<00:00,  3.71it/s, dice_loss - 0.168, iou_score - 0.7299]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.36it/s, dice_loss - 0.4197, iou_score - 0.4495]
#
# Epoch: 165
# train: 100%|██████████| 31/31 [00:07<00:00,  4.06it/s, dice_loss - 0.1644, iou_score - 0.7316]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.64it/s, dice_loss - 0.4057, iou_score - 0.4617]
#
# Epoch: 166
# train: 100%|██████████| 31/31 [00:07<00:00,  4.01it/s, dice_loss - 0.1644, iou_score - 0.7352]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.58it/s, dice_loss - 0.4186, iou_score - 0.4496]
#
# Epoch: 167
# train: 100%|██████████| 31/31 [00:07<00:00,  3.88it/s, dice_loss - 0.1457, iou_score - 0.7577]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.31it/s, dice_loss - 0.4172, iou_score - 0.4475]
#
# Epoch: 168
# train: 100%|██████████| 31/31 [00:08<00:00,  3.86it/s, dice_loss - 0.1518, iou_score - 0.7489]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.09it/s, dice_loss - 0.4092, iou_score - 0.4568]
#
# Epoch: 169
# train: 100%|██████████| 31/31 [00:08<00:00,  3.82it/s, dice_loss - 0.1504, iou_score - 0.7539]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.42it/s, dice_loss - 0.4106, iou_score - 0.4545]
#
# Epoch: 170
# train: 100%|██████████| 31/31 [00:07<00:00,  3.96it/s, dice_loss - 0.1643, iou_score - 0.7349]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.29it/s, dice_loss - 0.424, iou_score - 0.442]
#
# Epoch: 171
# train: 100%|██████████| 31/31 [00:08<00:00,  3.80it/s, dice_loss - 0.1421, iou_score - 0.7615]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.31it/s, dice_loss - 0.4288, iou_score - 0.4366]
#
# Epoch: 172
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.1573, iou_score - 0.7438]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.25it/s, dice_loss - 0.418, iou_score - 0.4477]
#
# Epoch: 173
# train: 100%|██████████| 31/31 [00:07<00:00,  3.90it/s, dice_loss - 0.1486, iou_score - 0.7561]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.72it/s, dice_loss - 0.4164, iou_score - 0.4493]
#
# Epoch: 174
# train: 100%|██████████| 31/31 [00:08<00:00,  3.77it/s, dice_loss - 0.1373, iou_score - 0.7723]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.12it/s, dice_loss - 0.4164, iou_score - 0.4487]
#
# Epoch: 175
# train: 100%|██████████| 31/31 [00:07<00:00,  3.89it/s, dice_loss - 0.1287, iou_score - 0.7807]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.84it/s, dice_loss - 0.4298, iou_score - 0.4399]
#
# Epoch: 176
# train: 100%|██████████| 31/31 [00:08<00:00,  3.79it/s, dice_loss - 0.1473, iou_score - 0.7577]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.27it/s, dice_loss - 0.4182, iou_score - 0.4495]
#
# Epoch: 177
# train: 100%|██████████| 31/31 [00:08<00:00,  3.87it/s, dice_loss - 0.172, iou_score - 0.7279]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.82it/s, dice_loss - 0.417, iou_score - 0.4485]
#
# Epoch: 178
# train: 100%|██████████| 31/31 [00:08<00:00,  3.73it/s, dice_loss - 0.1594, iou_score - 0.7413]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.24it/s, dice_loss - 0.4057, iou_score - 0.4562]
#
# Epoch: 179
# train: 100%|██████████| 31/31 [00:07<00:00,  3.98it/s, dice_loss - 0.1353, iou_score - 0.7727]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.95it/s, dice_loss - 0.4074, iou_score - 0.4555]
#
# Epoch: 180
# train: 100%|██████████| 31/31 [00:08<00:00,  3.80it/s, dice_loss - 0.1414, iou_score - 0.7673]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.47it/s, dice_loss - 0.4241, iou_score - 0.4411]
#
# Epoch: 181
# train: 100%|██████████| 31/31 [00:08<00:00,  3.76it/s, dice_loss - 0.1364, iou_score - 0.7746]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.95it/s, dice_loss - 0.4192, iou_score - 0.4463]
#
# Epoch: 182
# train: 100%|██████████| 31/31 [00:08<00:00,  3.87it/s, dice_loss - 0.1666, iou_score - 0.7341]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.79it/s, dice_loss - 0.4177, iou_score - 0.4478]
#
# Epoch: 183
# train: 100%|██████████| 31/31 [00:07<00:00,  3.98it/s, dice_loss - 0.1554, iou_score - 0.7477]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.82it/s, dice_loss - 0.4165, iou_score - 0.4495]
#
# Epoch: 184
# train: 100%|██████████| 31/31 [00:08<00:00,  3.84it/s, dice_loss - 0.1289, iou_score - 0.7823]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.84it/s, dice_loss - 0.4123, iou_score - 0.4511]
#
# Epoch: 185
# train: 100%|██████████| 31/31 [00:08<00:00,  3.57it/s, dice_loss - 0.1373, iou_score - 0.7707]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.75it/s, dice_loss - 0.4255, iou_score - 0.4413]
#
# Epoch: 186
# train: 100%|██████████| 31/31 [00:07<00:00,  3.93it/s, dice_loss - 0.1441, iou_score - 0.7626]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.91it/s, dice_loss - 0.4205, iou_score - 0.4465]
#
# Epoch: 187
# train: 100%|██████████| 31/31 [00:08<00:00,  3.80it/s, dice_loss - 0.1543, iou_score - 0.7469]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.96it/s, dice_loss - 0.4164, iou_score - 0.4488]
#
# Epoch: 188
# train: 100%|██████████| 31/31 [00:07<00:00,  4.07it/s, dice_loss - 0.1678, iou_score - 0.7315]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.90it/s, dice_loss - 0.4217, iou_score - 0.4418]
#
# Epoch: 189
# train: 100%|██████████| 31/31 [00:08<00:00,  3.82it/s, dice_loss - 0.1507, iou_score - 0.7507]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.53it/s, dice_loss - 0.4339, iou_score - 0.4345]
#
# Epoch: 190
# train: 100%|██████████| 31/31 [00:07<00:00,  3.90it/s, dice_loss - 0.1353, iou_score - 0.7749]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.19it/s, dice_loss - 0.4085, iou_score - 0.4563]
#
# Epoch: 191
# train: 100%|██████████| 31/31 [00:08<00:00,  3.84it/s, dice_loss - 0.1349, iou_score - 0.7733]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.49it/s, dice_loss - 0.4155, iou_score - 0.4476]
#
# Epoch: 192
# train: 100%|██████████| 31/31 [00:08<00:00,  3.73it/s, dice_loss - 0.1638, iou_score - 0.7442]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.51it/s, dice_loss - 0.419, iou_score - 0.4422]
#
# Epoch: 193
# train: 100%|██████████| 31/31 [00:08<00:00,  3.75it/s, dice_loss - 0.1858, iou_score - 0.7166]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.20it/s, dice_loss - 0.4061, iou_score - 0.4543]
#
# Epoch: 194
# train: 100%|██████████| 31/31 [00:07<00:00,  3.99it/s, dice_loss - 0.1508, iou_score - 0.7516]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.31it/s, dice_loss - 0.4102, iou_score - 0.451]
#
# Epoch: 195
# train: 100%|██████████| 31/31 [00:07<00:00,  4.03it/s, dice_loss - 0.1403, iou_score - 0.7699]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.31it/s, dice_loss - 0.4216, iou_score - 0.4433]
#
# Epoch: 196
# train: 100%|██████████| 31/31 [00:08<00:00,  3.81it/s, dice_loss - 0.1533, iou_score - 0.7514]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.16it/s, dice_loss - 0.404, iou_score - 0.4567]
#
# Epoch: 197
# train: 100%|██████████| 31/31 [00:08<00:00,  3.83it/s, dice_loss - 0.1421, iou_score - 0.765]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.20it/s, dice_loss - 0.4189, iou_score - 0.4476]
#
# Epoch: 198
# train: 100%|██████████| 31/31 [00:08<00:00,  3.76it/s, dice_loss - 0.1629, iou_score - 0.7418]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.84it/s, dice_loss - 0.3864, iou_score - 0.4737]
#
# Epoch: 199
# train: 100%|██████████| 31/31 [00:07<00:00,  3.89it/s, dice_loss - 0.1587, iou_score - 0.7505]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.52it/s, dice_loss - 0.4246, iou_score - 0.441]
#
# Epoch: 200
# train: 100%|██████████| 31/31 [00:07<00:00,  4.05it/s, dice_loss - 0.1551, iou_score - 0.7478]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.44it/s, dice_loss - 0.4135, iou_score - 0.4525]
#
# Epoch: 201
# train: 100%|██████████| 31/31 [00:08<00:00,  3.72it/s, dice_loss - 0.131, iou_score - 0.7816]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.21it/s, dice_loss - 0.4147, iou_score - 0.451]
#
# Epoch: 202
# train: 100%|██████████| 31/31 [00:08<00:00,  3.86it/s, dice_loss - 0.1267, iou_score - 0.7865]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.90it/s, dice_loss - 0.4015, iou_score - 0.4641]
#
# Epoch: 203
# train: 100%|██████████| 31/31 [00:07<00:00,  3.95it/s, dice_loss - 0.1434, iou_score - 0.7599]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.57it/s, dice_loss - 0.4126, iou_score - 0.455]
#
# Epoch: 204
# train: 100%|██████████| 31/31 [00:07<00:00,  3.99it/s, dice_loss - 0.1444, iou_score - 0.7619]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.01it/s, dice_loss - 0.4157, iou_score - 0.4541]
#
# Epoch: 205
# train: 100%|██████████| 31/31 [00:07<00:00,  3.95it/s, dice_loss - 0.1355, iou_score - 0.7764]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.42it/s, dice_loss - 0.4025, iou_score - 0.4609]
#
# Epoch: 206
# train: 100%|██████████| 31/31 [00:08<00:00,  3.76it/s, dice_loss - 0.1383, iou_score - 0.7674]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.77it/s, dice_loss - 0.3969, iou_score - 0.4661]
#
# Epoch: 207
# train: 100%|██████████| 31/31 [00:07<00:00,  3.99it/s, dice_loss - 0.1456, iou_score - 0.76]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.97it/s, dice_loss - 0.4098, iou_score - 0.4558]
#
# Epoch: 208
# train: 100%|██████████| 31/31 [00:08<00:00,  3.77it/s, dice_loss - 0.1566, iou_score - 0.7499]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.93it/s, dice_loss - 0.4081, iou_score - 0.4586]
#
# Epoch: 209
# train: 100%|██████████| 31/31 [00:07<00:00,  4.05it/s, dice_loss - 0.1474, iou_score - 0.7541]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.33it/s, dice_loss - 0.4184, iou_score - 0.4516]
#
# Epoch: 210
# train: 100%|██████████| 31/31 [00:07<00:00,  3.95it/s, dice_loss - 0.1465, iou_score - 0.7586]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.33it/s, dice_loss - 0.4091, iou_score - 0.4607]
#
# Epoch: 211
# train: 100%|██████████| 31/31 [00:08<00:00,  3.84it/s, dice_loss - 0.1552, iou_score - 0.7474]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.66it/s, dice_loss - 0.3888, iou_score - 0.4714]
#
# Epoch: 212
# train: 100%|██████████| 31/31 [00:08<00:00,  3.71it/s, dice_loss - 0.1453, iou_score - 0.762]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.56it/s, dice_loss - 0.4018, iou_score - 0.4605]
#
# Epoch: 213
# train: 100%|██████████| 31/31 [00:07<00:00,  3.94it/s, dice_loss - 0.1548, iou_score - 0.7442]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.32it/s, dice_loss - 0.4005, iou_score - 0.4615]
#
# Epoch: 214
# train: 100%|██████████| 31/31 [00:08<00:00,  3.81it/s, dice_loss - 0.137, iou_score - 0.7714]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.19it/s, dice_loss - 0.3996, iou_score - 0.4698]
#
# Epoch: 215
# train: 100%|██████████| 31/31 [00:07<00:00,  3.90it/s, dice_loss - 0.1486, iou_score - 0.7549]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.34it/s, dice_loss - 0.3965, iou_score - 0.4665]
#
# Epoch: 216
# train: 100%|██████████| 31/31 [00:07<00:00,  3.95it/s, dice_loss - 0.1566, iou_score - 0.7478]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.19it/s, dice_loss - 0.3856, iou_score - 0.481]
# Model saved!
#
# Epoch: 217
# train: 100%|██████████| 31/31 [00:08<00:00,  3.87it/s, dice_loss - 0.1451, iou_score - 0.7586]
# valid: 100%|██████████| 8/8 [00:00<00:00, 11.23it/s, dice_loss - 0.4008, iou_score - 0.4625]
#
# Epoch: 218
# train: 100%|██████████| 31/31 [00:08<00:00,  3.70it/s, dice_loss - 0.1324, iou_score - 0.776]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.96it/s, dice_loss - 0.4206, iou_score - 0.449]
#
# Epoch: 219
# train: 100%|██████████| 31/31 [00:08<00:00,  3.73it/s, dice_loss - 0.1474, iou_score - 0.7572]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.27it/s, dice_loss - 0.3981, iou_score - 0.4665]
#
# Epoch: 220
# train: 100%|██████████| 31/31 [00:08<00:00,  3.68it/s, dice_loss - 0.1244, iou_score - 0.7905]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.73it/s, dice_loss - 0.3944, iou_score - 0.4687]
#
# Epoch: 221
# train: 100%|██████████| 31/31 [00:07<00:00,  3.92it/s, dice_loss - 0.1281, iou_score - 0.7859]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.36it/s, dice_loss - 0.3972, iou_score - 0.4694]
#
# Epoch: 222
# train: 100%|██████████| 31/31 [00:07<00:00,  3.91it/s, dice_loss - 0.1428, iou_score - 0.7669]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.95it/s, dice_loss - 0.4055, iou_score - 0.4597]
#
# Epoch: 223
# train: 100%|██████████| 31/31 [00:08<00:00,  3.76it/s, dice_loss - 0.1389, iou_score - 0.7682]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.52it/s, dice_loss - 0.4109, iou_score - 0.4564]
#
# Epoch: 224
# train: 100%|██████████| 31/31 [00:08<00:00,  3.66it/s, dice_loss - 0.1394, iou_score - 0.7669]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.58it/s, dice_loss - 0.4008, iou_score - 0.4645]
#
# Epoch: 225
# train: 100%|██████████| 31/31 [00:08<00:00,  3.58it/s, dice_loss - 0.1346, iou_score - 0.7774]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.27it/s, dice_loss - 0.4012, iou_score - 0.4627]
#
# Epoch: 226
# train: 100%|██████████| 31/31 [00:07<00:00,  3.88it/s, dice_loss - 0.1449, iou_score - 0.7619]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.37it/s, dice_loss - 0.3928, iou_score - 0.4695]
#
# Epoch: 227
# train: 100%|██████████| 31/31 [00:08<00:00,  3.83it/s, dice_loss - 0.168, iou_score - 0.7279]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.10it/s, dice_loss - 0.4089, iou_score - 0.4564]
#
# Epoch: 228
# train: 100%|██████████| 31/31 [00:07<00:00,  4.00it/s, dice_loss - 0.1459, iou_score - 0.7615]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.13it/s, dice_loss - 0.3934, iou_score - 0.4689]
#
# Epoch: 229
# train: 100%|██████████| 31/31 [00:08<00:00,  3.79it/s, dice_loss - 0.1197, iou_score - 0.7965]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.95it/s, dice_loss - 0.3975, iou_score - 0.4701]
#
# Epoch: 230
# train: 100%|██████████| 31/31 [00:07<00:00,  3.88it/s, dice_loss - 0.1292, iou_score - 0.7855]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.02it/s, dice_loss - 0.3997, iou_score - 0.4638]
#
# Epoch: 231
# train: 100%|██████████| 31/31 [00:08<00:00,  3.81it/s, dice_loss - 0.1343, iou_score - 0.774]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.43it/s, dice_loss - 0.4023, iou_score - 0.466]
#
# Epoch: 232
# train: 100%|██████████| 31/31 [00:08<00:00,  3.85it/s, dice_loss - 0.147, iou_score - 0.7569]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.91it/s, dice_loss - 0.3863, iou_score - 0.4784]
#
# Epoch: 233
# train: 100%|██████████| 31/31 [00:08<00:00,  3.72it/s, dice_loss - 0.1594, iou_score - 0.7388]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.74it/s, dice_loss - 0.4238, iou_score - 0.4486]
#
# Epoch: 234
# train: 100%|██████████| 31/31 [00:07<00:00,  3.96it/s, dice_loss - 0.1301, iou_score - 0.7802]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.11it/s, dice_loss - 0.3848, iou_score - 0.4789]
#
# Epoch: 235
# train: 100%|██████████| 31/31 [00:08<00:00,  3.87it/s, dice_loss - 0.1189, iou_score - 0.7996]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.82it/s, dice_loss - 0.3981, iou_score - 0.47]
#
# Epoch: 236
# train: 100%|██████████| 31/31 [00:08<00:00,  3.73it/s, dice_loss - 0.1314, iou_score - 0.7792]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.97it/s, dice_loss - 0.3946, iou_score - 0.4693]
#
# Epoch: 237
# train: 100%|██████████| 31/31 [00:07<00:00,  3.97it/s, dice_loss - 0.1385, iou_score - 0.7686]
# valid: 100%|██████████| 8/8 [00:00<00:00, 13.80it/s, dice_loss - 0.3977, iou_score - 0.4668]
#
# Epoch: 238
# train: 100%|██████████| 31/31 [00:08<00:00,  3.85it/s, dice_loss - 0.1482, iou_score - 0.76]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.28it/s, dice_loss - 0.3938, iou_score - 0.4714]
#
# Epoch: 239
# train: 100%|██████████| 31/31 [00:08<00:00,  3.85it/s, dice_loss - 0.1414, iou_score - 0.7624]
# valid: 100%|██████████| 8/8 [00:00<00:00, 14.10it/s, dice_loss - 0.4009, iou_score - 0.464]
#
# Epoch: 240
# ...
# [0.5409696027636528, 0.49964426457881933, 0.6609915941953659, 0.5486074611544609, 0.600694365799427, 0.6247977018356323, 0.6360062807798386, 0.6639702022075654, 0.7257841527462006, 0.6670187115669252, 0.6508037820458413, 0.6573749631643295, 0.5953563675284387, 0.7692804858088493, 0.6781089380383492, 0.7599344179034233, 0.6670125648379326, 0.5133082941174507, 0.6248735338449478, 0.62813588231802, 0.6463949307799339, 0.718434564769268, 0.7240926250815392, 0.6126684918999672, 0.7268433719873428, 0.6781910136342049, 0.7137006372213364, 0.5887376442551613, 0.6261275261640549, 0.5371047183871269, 0.5920005738735199, 0.6505694761872292, 0.6088762506842613, 0.6379620134830475, 0.6347687765955925, 0.603987380862236, 0.5660570934414862, 0.5038176476955414, 0.5078853741288185, 0.5099882557988167, 0.5860908403992653, 0.5130140110850334, 0.5768925473093987, 0.5317784920334816, 0.5982706174254417, 0.5449398085474968, 0.574758730828762, 0.5173102244734764, 0.5058081820607185, 0.5724352300167084, 0.4910750091075897, 0.6043935269117355, 0.6250715628266335, 0.46110983192920685, 0.48385920375585545, 0.4895939975976944, 0.5023132264614105, 0.4743043780326843, 0.4791467040777207, 0.44284254312515253, 0.44296788424253464, 0.48879580199718475, 0.5737256035208702, 0.48765613883733744, 0.5505791306495665, 0.6268673092126846, 0.5257797688245773, 0.5225844159722328, 0.5696714296936989, 0.559108704328537, 0.516864001750946, 0.5653983652591705, 0.46483471244573593, 0.46892078220844263, 0.43793949484825134, 0.4283968210220337, 0.4215099588036538, 0.43905889987945557, 0.6000710055232048, 0.46699476242065435, 0.5860601514577866, 0.5915669649839401, 0.4798992797732353, 0.44649661332368845, 0.5115197747945786, 0.4852142035961151, 0.4817337244749069, 0.46745304763317097, 0.46757739782333374, 0.5092339888215065, 0.5296978056430817, 0.4836783111095428, 0.49624550342559803, 0.4454983696341514, 0.47619555890560156, 0.5853529125452042, 0.5428284555673599, 0.4609117358922959, 0.43900856375694275, 0.47032434493303305, 0.6322421804070473, 0.5891004055738449, 0.5218573957681656, 0.45659286528825754, 0.5558788105845452, 0.5168950632214546, 0.4802530035376549, 0.4769430458545685, 0.45670777559280396, 0.4543343931436538, 0.45628007501363754, 0.41336818039417267, 0.44970522075891495, 0.45104157924652094, 0.4551076516509056, 0.430025190114975, 0.40850488841533655, 0.39235224574804306, 0.40533877909183497, 0.412406750023365, 0.4285516291856766, 0.4503075331449509, 0.39407869428396225, 0.42843297868967056, 0.4750219136476517, 0.4194259122014046, 0.38030894845724106, 0.4166928008198738, 0.4312891364097595, 0.4656422734260559, 0.4755281955003739, 0.4332076236605644, 0.4180266484618187, 0.43433654308319086, 0.44397830218076706, 0.4259460493922233, 0.4546495899558067, 0.43749856948852545, 0.4298652783036232, 0.4174501970410347, 0.4314019829034805, 0.4219815209507942, 0.4834342077374459, 0.45887781679630285, 0.47308562695980066, 0.43880095332860947, 0.3901319950819015, 0.4695384725928306, 0.4161784425377845, 0.40945883095264435, 0.42460662126541143, 0.42829848825931544, 0.42009466141462326, 0.41817229986190796, 0.42466925829648966, 0.40932992845773697, 0.40895503014326096, 0.4092331528663635, 0.41529008001089096, 0.41386906802654266, 0.4123326614499092, 0.4137498512864113, 0.4034123793244362, 0.4088431671261788, 0.41970171779394144, 0.4056690186262131, 0.41860648244619364, 0.41718112677335734, 0.40920934826135635, 0.41058959066867834, 0.42401932179927826, 0.4287577867507934, 0.4179698973894119, 0.416414387524128, 0.4164419174194336, 0.42982902377843857, 0.4182364344596863, 0.41703959554433817, 0.4057105705142022, 0.4073787108063697, 0.4240608662366867, 0.4192333891987801, 0.4176577478647232, 0.41650564968585974, 0.41226333379745483, 0.42545699328184133, 0.4205261692404747, 0.4164483919739723, 0.421651154756546, 0.4338963776826858, 0.40852911770343786, 0.415511354804039, 0.4190187007188798, 0.40614184737205505, 0.4102470278739929, 0.42160303890705114, 0.40403047204017634, 0.41892629 ...
# [0.1838390188471925, 0.29112609221990554, 0.3154377388100607, 0.3359824686100886, 0.3801670305190549, 0.37226412950055593, 0.36959623064725633, 0.38669741153736154, 0.38368291816403793, 0.4225210958430844, 0.42285925366224775, 0.44556288132744454, 0.42240593630460005, 0.4399331897016494, 0.4426776161116939, 0.46172146331022573, 0.46695151997189366, 0.4585120323444566, 0.48861062526702875, 0.47761571695727695, 0.4460118523528499, 0.5074196678976858, 0.5203683866608526, 0.506958961967499, 0.48548732746031964, 0.46747722476720804, 0.5250501656728143, 0.5040663870111588, 0.49721983700029315, 0.5394701428951756, 0.5180806594510232, 0.5568886836690288, 0.5022514981615188, 0.542054718540561, 0.529693715515667, 0.5474980675405072, 0.5732650093493924, 0.5214826063283028, 0.5374145344380409, 0.5461856992013993, 0.5300720050450294, 0.5704962370857117, 0.5612221802456132, 0.5503063403790999, 0.5667253333714699, 0.5528262714224478, 0.5985403801164318, 0.5729161182478553, 0.5599085967386923, 0.5349319413785013, 0.5400083722666867, 0.5627519368164001, 0.5811918031784797, 0.5924307083891285, 0.6128042306630843, 0.5840742583236387, 0.5820803176010807, 0.638575561584965, 0.6015865648946455, 0.6021677005675531, 0.6092649955422648, 0.5953939871922614, 0.5922925145395341, 0.6193680744017325, 0.5978432365002171, 0.5932313117288776, 0.654152185686173, 0.6299624096962713, 0.6289265107723974, 0.6132372117811633, 0.5910823748957726, 0.6321207621430193, 0.6039842641161335, 0.656018646494035, 0.613913918695142, 0.6309629553748716, 0.6089572142208777, 0.5984276754240835, 0.6072626238869082, 0.5905923434803562, 0.6436683756689873, 0.6547958797985507, 0.6473978661721753, 0.6434234568188267, 0.6397937824649195, 0.5817565821832228, 0.5789275856748705, 0.6316170519398104, 0.6337145336212652, 0.6483927667140961, 0.6183435412183885, 0.6727893900486731, 0.6783734709024429, 0.6702970920070526, 0.6499661389858491, 0.6892435781417353, 0.673230811472862, 0.6692408486720057, 0.6530852385105627, 0.6876237988471985, 0.6393936459095247, 0.7089544486614964, 0.6635350575370174, 0.6523057293267018, 0.6906648359952435, 0.655564849415133, 0.6810799692907642, 0.6961426052355, 0.5903024221620252, 0.646592604537164, 0.6442108106228613, 0.6934561662135584, 0.6893354798516919, 0.660737399132021, 0.6553357560788431, 0.6785845987258419, 0.6987823834342342, 0.6860585611674094, 0.6860005586378036, 0.6672860941579266, 0.6855822871288945, 0.6890617061045862, 0.684354156255722, 0.6581513309671034, 0.6762212447581751, 0.6871498717415719, 0.6872566063557903, 0.6967650103953577, 0.687068728669997, 0.6933914692171157, 0.7036377826044635, 0.6937994831992732, 0.7134398914152577, 0.7037904089496982, 0.713007253985251, 0.7077467316581356, 0.695790697490015, 0.7057086767688874, 0.7077769415993845, 0.719660170616642, 0.7100363325688147, 0.7432000002553386, 0.6786831802418155, 0.7172021548594197, 0.7063870324242499, 0.7196836577307794, 0.7235080686307724, 0.73419391147552, 0.7061969277358823, 0.7112109218874287, 0.7239875072433102, 0.7485210549446845, 0.7052034283837963, 0.7381907201582387, 0.7404939926439718, 0.7532409054617727, 0.737214389347261, 0.7520965683844782, 0.77133467120509, 0.7315287628481466, 0.7407605849927469, 0.7553560743408818, 0.7230504385886652, 0.7473337352275847, 0.7299204103408319, 0.731625755948405, 0.7351997754266185, 0.7577365511848081, 0.7489100165905491, 0.7538625184566743, 0.7348884411396519, 0.7614683306986286, 0.743813838689558, 0.7561200434161771, 0.7723280489444734, 0.7806609196047629, 0.7576816187750909, 0.7279141545295715, 0.7413264464947485, 0.7726524991373862, 0.7672840837509401, 0.7746338229025564, 0.734102338552475, 0.7476719819730329, 0.7823058443684731, 0.770740037002871, 0.7625919936164733, 0.7468983482929966, 0.7315405049631672, 0.7506546714613516, 0.7748609012173069, 0.7733199615632335, 0.7442261031077753, 0.7165842469060615, 0.7516089889311021, 0.7698591947555544, 0.7514097036853914, 0.7649909565525671, 0.7418194216105246, 0.7504539617126987, 0.7478113318 ...
# [0.3498160932213068, 0.367822989821434, 0.229528316318452, 0.32030104567085116, 0.2776106186465821, 0.2840338605528018, 0.2667282293651969, 0.24851283806242197, 0.19158930054912285, 0.23537533174022052, 0.24623084349815955, 0.2377191186146069, 0.2784001007858873, 0.15240496213301036, 0.22392691860953284, 0.16732041168185297, 0.23759848021655294, 0.3567155413401565, 0.2625084165738425, 0.2541080941696809, 0.24081872776870333, 0.19642674832357976, 0.19796729928860382, 0.2714474406348071, 0.19391343757042817, 0.22816869619278818, 0.19720870631073825, 0.28274259438133126, 0.2643534662456712, 0.3300280906442762, 0.2784043085012794, 0.2380988467667461, 0.2804239867509804, 0.2558531891809306, 0.25865593740681414, 0.2810676247064234, 0.30692723488399987, 0.3556907288912893, 0.3498734589848877, 0.356981549430287, 0.2911406215463043, 0.35513201544026146, 0.2976686358634592, 0.33664234356919537, 0.2819107212309004, 0.32747220994869475, 0.300378962438202, 0.34850558826664696, 0.35365012288093567, 0.3081503100693226, 0.3562383111566305, 0.28175456679122546, 0.2585837450061203, 0.4049836546182632, 0.3782094530761242, 0.3780513405799866, 0.3537570536136627, 0.3790463972836733, 0.37885711435228586, 0.407095143571496, 0.40679471381008625, 0.36262032948434353, 0.30121338926840635, 0.36175791919231415, 0.3141795489937067, 0.2550271274521947, 0.34070051880553365, 0.3391291815787554, 0.30938283540308475, 0.3130796756595373, 0.3497863961383701, 0.30438908934593195, 0.40178373735398054, 0.39441295340657234, 0.41184888407588, 0.4271872490644455, 0.4303439315408468, 0.4131972473114729, 0.2757056327536702, 0.3860052190721035, 0.29743446969215476, 0.2881649835107168, 0.3715390060096979, 0.40584206208586693, 0.3540682122183284, 0.38277765549719334, 0.39058301225304604, 0.40337745705619454, 0.38855714723467827, 0.37043934827670455, 0.3499379954300821, 0.39300500974352465, 0.37814959697718725, 0.41820126213133335, 0.3813195452094078, 0.29550777678377926, 0.3412826252169907, 0.4019885994493961, 0.4346474651247263, 0.4014822170138359, 0.27252384391906664, 0.30224109348203043, 0.36423170985653996, 0.41675747372210026, 0.3284673891030252, 0.3539541298523545, 0.38793293200433254, 0.4014166034758091, 0.39843725599348545, 0.40493407286703587, 0.4080615509301424, 0.4459894485771656, 0.4358404567465186, 0.4268489973619581, 0.4165128255262971, 0.43965434469282627, 0.45491356030106544, 0.47098855674266815, 0.45597695372998714, 0.4503573700785637, 0.4334085714071989, 0.4206685312092304, 0.4633600786328316, 0.4316211882978678, 0.39452601317316294, 0.44445702619850636, 0.4791187737137079, 0.4498653281480074, 0.45022230315953493, 0.42284929810557514, 0.3989501828327775, 0.42673955671489233, 0.4460450168699026, 0.43145214207470417, 0.4372642720118165, 0.4517394220456481, 0.429493434727192, 0.43404725566506386, 0.4421043023467064, 0.4593307953327894, 0.44304873887449503, 0.4467538557946682, 0.3899667006917298, 0.39778564497828484, 0.37966495007276535, 0.42104960046708584, 0.46880157478153706, 0.3978340234607458, 0.458721574395895, 0.461096384562552, 0.44514164607971907, 0.4420239934697747, 0.4488295391201973, 0.4479113621637225, 0.44444991927593946, 0.45566354505717754, 0.45827954914420843, 0.46183687914162874, 0.4557377742603421, 0.45217858627438545, 0.45827741269022226, 0.45588462613523006, 0.46215521171689034, 0.4576322780922055, 0.4495494579896331, 0.461670845746994, 0.4495995072647929, 0.44751524180173874, 0.4568146439269185, 0.4544546343386173, 0.44201515056192875, 0.4365530693903565, 0.4476693896576762, 0.44930901750922203, 0.4486925760284066, 0.43985760770738125, 0.44953331630676985, 0.44847047608345747, 0.4562478717416525, 0.4555234499275685, 0.4410919826477766, 0.4462842606008053, 0.44777690060436726, 0.4495150903239846, 0.45112439803779125, 0.4412555582821369, 0.44651363231241703, 0.4488468253985048, 0.4417698960751295, 0.43450901936739683, 0.4562705513089895, 0.4475907292217016, 0.4421623442322016, 0.4542842321097851, 0.45104253478348255, 0.4433130342513323, 0. ...

# %%
import pandas as pd
metrics = pd.DataFrame({
    "epoch":range(400),
    "train_loss":train_loss,
    "val_loss":val_loss,
    "train_iou":train_iou,
    "val_iou":val_iou
})

metrics.to_csv("parts_log.csv", sep=',', encoding='utf-8', index=False)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
file = pd.read_csv('parts_log.csv')
lines = file.plot.line(x='epoch', y=['train_loss', 'val_loss', 'train_iou', 'val_iou'])
plt.title('CNN learning curves')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['training', 'validation','training', 'validation'], loc='lower right')
plt.show()

# %%
# !ls '/content/drive/My Drive/task_artivartic/dataset/test'
# Out:
# 11.jpg	12.jpg	28.jpg	45.jpg	60.jpg	66.jpg	67.jpg	72.jpg

# %%
import cv2 
import numpy as np 

model = torch.load('/content/drive/My Drive/task_artivartic/weights/damage_seg.pth')


image_size = 224
_transform = [
      albu.Resize(image_size, image_size, p=1),
      albu.Lambda(image=preprocessing_fn),
      albu.Lambda(image=to_tensor),
  ]
trans = albu.Compose(_transform)
for file_name in os.listdir('/content/drive/My Drive/task_artivartic/dataset/test'):
  print(file_name)
  _frame = cv2.imread('/content/drive/My Drive/task_artivartic/dataset/test/'+str(file_name))
  frame = trans(image=_frame)
  abc  = torch.unsqueeze(torch.Tensor(frame["image"]), dim = 0)
  ans = model(abc.cuda())
  ans = ans.squeeze().cpu().detach().numpy()
  print(ans.shape)
  ans = ans[np.newaxis,...]

  ans = np.transpose(ans, (1, 2, 0))
  ans = ans*255
  print(ans.shape)
  visualize(image=_frame, mask0=ans.squeeze())
# Out:
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2908: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "
# 45.jpg
# (224, 224)
# (224, 224, 1)
# 66.jpg
# (224, 224)
# (224, 224, 1)
# 28.jpg
# (224, 224)
# (224, 224, 1)
# 72.jpg
# (224, 224)
# (224, 224, 1)
# 12.jpg
# (224, 224)
# (224, 224, 1)
# 67.jpg
# (224, 224)
# (224, 224, 1)
# 60.jpg
# (224, 224)
# (224, 224, 1)
# 11.jpg
# (224, 224)
# (224, 224, 1)
